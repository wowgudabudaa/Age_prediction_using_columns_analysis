# %%
# === Path Variables ===# Healthy

import os  # For handling file paths and directories
import pandas as pd  # For working with tabular data using DataFrames
import matplotlib.pyplot as plt  # For generating plots
import seaborn as sns  # For enhanced visualizations of heatmaps
import zipfile  # For reading compressed files without extracting them
import re  # For extracting numerical IDs using regular expressions

import torch
import random
import numpy as np

import os
import pandas as pd
import numpy as np

import networkx as nx  # For graph-level metrics


BASE_DIR = "../../input_columns_1mm/input_columns"
SUBJECT_IDS_CSV = "../age_prediction_on_columns_analyses/subject_ids.csv"
AGE_CSV = "../age_prediction_on_columns_analyses/ages.csv"
subject_df = pd.read_csv(SUBJECT_IDS_CSV, header=None)
age_df = pd.read_csv(AGE_CSV, header=None)
metadata_path = "../../AD_DECODE_data3.xlsx"
df_metadata = pd.read_excel(metadata_path)

# %%
# === Set seed for reproducibility ===
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

#Load columns

# Base directory where subject folders (e.g., S00775_columns_1mm) are stored

# %%
# List of hemispheres
HEMIS = ["lh", "rh"]

# %%
# List of cortical regions (based on the parcellation used)
REGION_NAMES = ['bankssts',
'caudalanteriorcingulate',
'caudalmiddlefrontal',
'cuneus',
'entorhinal',
'fusiform',
'inferiorparietal',
'inferiortemporal',
'isthmuscingulate',
'lateraloccipital',
'lateralorbitofrontal',
'lingual',
'medialorbitofrontal',
'middletemporal',
'parahippocampal',
'paracentral',
'parsopercularis',
'parsorbitalis',
'parstriangularis',
'pericalcarine',
'postcentral',
'posteriorcingulate',
'precentral',
'precuneus',
'rostralanteriorcingulate',
'rostralmiddlefrontal',
'superiorfrontal',
'superiorparietal',
'superiortemporal',
'supramarginal',
'frontalpole',
'temporalpole',
'transversetemporal',
'insula'
]

# %%
############################## METADATA ##############################

print("ADDECODE METADATA\n")
# Out:
# ADDECODE METADATA

# %%
# Zero-pad subject IDs to 5-digit strings
subject_ids = subject_df[0].astype(str).apply(lambda x: x.zfill(5)).tolist()

# %%
# Standardize MRI_Exam IDs
df_metadata["MRI_Exam_fixed"] = (
    df_metadata["MRI_Exam"]
    .fillna(0)
    .astype(int)
    .astype(str)
    .str.zfill(5)
)

# %%
# Drop fully empty rows and rows missing MRI_Exam
df_metadata_cleaned = df_metadata.dropna(how="all")
df_metadata_cleaned = df_metadata_cleaned.dropna(subset=["MRI_Exam"])

# %%
# === Filter metadata to match only included subject IDs ===
df_matched = df_metadata_cleaned[df_metadata_cleaned["MRI_Exam_fixed"].isin(subject_ids)].copy()

# %%
# === Only keep valid IDs for reordering to avoid KeyError ===
valid_ids = [sid for sid in subject_ids if sid in df_matched["MRI_Exam_fixed"].values]

# %%
# === Reorder safely ===
df_matched = df_matched.set_index("MRI_Exam_fixed").loc[valid_ids].reset_index()

# %%
# === Clean 'Risk' column: treat NaNs and empty strings as 'NoRisk' ===
df_matched["Risk"] = (
    df_matched["Risk"]
    .fillna("NoRisk")                              # Replace NaNs
    .replace(r'^\s*$', "NoRisk", regex=True)       # Replace empty strings or whitespace
    .str.strip()                                   # Remove leading/trailing spaces
)

# %%
# === Filter only healthy or familial risk subjects ===
df_matched_filtered = df_matched[df_matched["Risk"].isin(["NoRisk", "Familial"])].copy()

# %%
# === Print summary ===
print("Remaining risk group distribution:")
print(df_matched_filtered["Risk"].value_counts())
print(f"\nSubjects before filtering: {len(df_matched)}")
print(f"Subjects after filtering:  {len(df_matched_filtered)}")
# Out:
# Remaining risk group distribution:
# Risk
# Familial    48
# NoRisk      19
# Name: count, dtype: int64
#
# Subjects before filtering: 72
# Subjects after filtering:  67

# %%
# Build age_dict from the healthy metadata dataframe
age_dict = dict(zip(df_matched_filtered["MRI_Exam_fixed"], df_matched_filtered["age"]))

# %%
# === Extract filtered subject IDs (already cleaned and filtered to NoRisk / Familial) ===
subject_ids = df_matched_filtered["MRI_Exam_fixed"].tolist()

# %%
# === Initialize final dictionary: subject_id -> region -> matrix ===
column_data = {}

# %%
# === Loop through filtered subjects ===
for subj_id in subject_ids:
    subj_dict = {}
    subj_dir = os.path.join(BASE_DIR, f"S{subj_id}_columns_1mm")  # Path to subject's folder

    for hemi in HEMIS:
        for region in REGION_NAMES:
            region_key = f"{hemi}_{region}"
            filename = f"S{subj_id}_{region_key}_md.csv"
            filepath = os.path.join(subj_dir, filename)

            if not os.path.exists(filepath):
                print(f"[WARNING] Missing: {filepath}")
                continue


            # Load CSV matrix as numpy array (float32)
            mat = pd.read_csv(filepath, header=None).values.astype(np.float32)
            subj_dict[region_key] = mat

    if len(subj_dict) > 0:
        column_data[subj_id] = subj_dict
    else:
        print(f"[INFO] Skipping subject {subj_id} (no valid regions found)")
# Out:
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_bankssts_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_caudalanteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_caudalmiddlefrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_cuneus_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_entorhinal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_fusiform_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_inferiorparietal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_inferiortemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_isthmuscingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_lateraloccipital_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_lateralorbitofrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_lingual_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_medialorbitofrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_middletemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_parahippocampal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_paracentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_parsopercularis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_parsorbitalis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_parstriangularis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_pericalcarine_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_postcentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_posteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_precentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_precuneus_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_rostralanteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_rostralmiddlefrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_superiorfrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_superiorparietal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_superiortemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_supramarginal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_frontalpole_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_temporalpole_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_transversetemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_lh_insula_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_bankssts_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_caudalanteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_caudalmiddlefrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_cuneus_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_entorhinal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_fusiform_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_inferiorparietal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_inferiortemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_isthmuscingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_lateraloccipital_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_lateralorbitofrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_lingual_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_medialorbitofrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_middletemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_parahippocampal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_paracentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_parsopercularis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_parsorbitalis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_parstriangularis_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_pericalcarine_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_postcentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_posteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_precentral_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_precuneus_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_rostralanteriorcingulate_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_rostralmiddlefrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_superiorfrontal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_superiorparietal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_superiortemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_supramarginal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_frontalpole_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_temporalpole_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_transversetemporal_md.csv
# [WARNING] Missing: ../../input_columns_1mm/input_columns\S03866_columns_1mm\S03866_rh_insula_md.csv
# [INFO] Skipping subject 03866 (no valid regions found)

# %%
# === OPTIONAL: Print region shapes for each subject ===
for subj_id, regions in column_data.items():
    print(f"\nSubject {subj_id}:")
    for region_name, matrix in regions.items():
        print(f"  {region_name} → {matrix.shape}")
# Out:
# Subject 02110:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02363:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02373:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02386:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02390:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02231:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02402:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02410:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02421:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 01912:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02424:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02446:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02451:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02485:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02473:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02491:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02506:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02524:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02535:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02654:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02666:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02690:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02695:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 02715:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
# ...
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 03896:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 00775:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 04493:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 01412:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 04526:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 01470:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)
#
# Subject 01619:
#   lh_bankssts → (1, 21)
#   lh_caudalanteriorcingulate → (1, 21)
#   lh_caudalmiddlefrontal → (1, 21)
#   lh_cuneus → (1, 21)
#   lh_entorhinal → (1, 21)
#   lh_fusiform → (1, 21)
#   lh_inferiorparietal → (1, 21)
#   lh_inferiortemporal → (1, 21)
#   lh_isthmuscingulate → (1, 21)
#   lh_lateraloccipital → (1, 21)
#   lh_lateralorbitofrontal → (1, 21)
#   lh_lingual → (1, 21)
#   lh_medialorbitofrontal → (1, 21)
#   lh_middletemporal → (1, 21)
#   lh_parahippocampal → (1, 21)
#   lh_paracentral → (1, 21)
#   lh_parsopercularis → (1, 21)
#   lh_parsorbitalis → (1, 21)
#   lh_parstriangularis → (1, 21)
#   lh_pericalcarine → (1, 21)
#   lh_postcentral → (1, 21)
#   lh_posteriorcingulate → (1, 21)
#   lh_precentral → (1, 21)
#   lh_precuneus → (1, 21)
#   lh_rostralanteriorcingulate → (1, 21)
#   lh_rostralmiddlefrontal → (1, 21)
#   lh_superiorfrontal → (1, 21)
#   lh_superiorparietal → (1, 21)
#   lh_superiortemporal → (1, 21)
#   lh_supramarginal → (1, 21)
#   lh_frontalpole → (1, 21)
#   lh_temporalpole → (1, 21)
#   lh_transversetemporal → (1, 21)
#   lh_insula → (1, 21)
#   rh_bankssts → (1, 21)
#   rh_caudalanteriorcingulate → (1, 21)
#   rh_caudalmiddlefrontal → (1, 21)
#   rh_cuneus → (1, 21)
#   rh_entorhinal → (1, 21)
#   rh_fusiform → (1, 21)
#   rh_inferiorparietal → (1, 21)
#   rh_inferiortemporal → (1, 21)
#   rh_isthmuscingulate → (1, 21)
#   rh_lateraloccipital → (1, 21)
#   rh_lateralorbitofrontal → (1, 21)
#   rh_lingual → (1, 21)
#   rh_medialorbitofrontal → (1, 21)
#   rh_middletemporal → (1, 21)
#   rh_parahippocampal → (1, 21)
#   rh_paracentral → (1, 21)
#   rh_parsopercularis → (1, 21)
#   rh_parsorbitalis → (1, 21)
#   rh_parstriangularis → (1, 21)
#   rh_pericalcarine → (1, 21)
#   rh_postcentral → (1, 21)
#   rh_posteriorcingulate → (1, 21)
#   rh_precentral → (1, 21)
#   rh_precuneus → (1, 21)
#   rh_rostralanteriorcingulate → (1, 21)
#   rh_rostralmiddlefrontal → (1, 21)
#   rh_superiorfrontal → (1, 21)
#   rh_superiorparietal → (1, 21)
#   rh_superiortemporal → (1, 21)
#   rh_supramarginal → (1, 21)
#   rh_frontalpole → (1, 21)
#   rh_temporalpole → (1, 21)
#   rh_transversetemporal → (1, 21)
#   rh_insula → (1, 21)

# %%
# CONSTRUCT GRAPHS 

import os
import numpy as np
import pandas as pd
import torch
from torch_geometric.data import Data
from sklearn.neighbors import NearestNeighbors

# %%
# Get subject's data (dict: region → matrix)
subject_data = column_data[subj_id]

#Normalize
from sklearn.preprocessing import StandardScaler

# Concatenate all regions for one subject
x_np = np.vstack(list(subject_data.values()))  # shape [n_total_columns, 21]

# Z-score normalization across all features (columns)
scaler = StandardScaler()
x_np = scaler.fit_transform(x_np)

# %%
# === STEP 1: Build edge_index from K-Nearest Neighbors ===

def build_knn_edge_index(x_np, k=10):
    """
    Builds the edge_index for a graph using KNN based on node features.

    Args:
        x_np (np.ndarray): shape [n_nodes, n_features]
        k (int): number of neighbors per node

    Returns:
        edge_index (torch.LongTensor): shape [2, num_edges]
    """
    knn = NearestNeighbors(n_neighbors=k, metric="euclidean")
    knn.fit(x_np)
    knn_graph = knn.kneighbors_graph(x_np).tocoo()

    edge_index = torch.tensor(
        np.vstack((knn_graph.row, knn_graph.col)),
        dtype=torch.long
    )
    return edge_index

# %%
# === STEP 2: Build PyG graph from a single subject ===

def build_graph_from_subject(subj_id, column_data, age_dict, k=10):
    """
    Converts one subject's cortical column data into a PyTorch Geometric graph.

    Args:
        subj_id (str): subject ID
        column_data (dict): {subject_id → {region_name → matrix}}
        age_dict (dict): {subject_id → age}
        k (int): number of KNN neighbors

    Returns:
        Data: PyTorch Geometric graph with x, edge_index, y
    """

    # Get all regions from this subject and stack all columns
    subj_regions = column_data[subj_id]
    x_np = np.vstack(list(subj_regions.values()))  # shape [n_columns_total, 21]


    # Convert features to tensor
    x = torch.tensor(x_np, dtype=torch.float32)


    # Build edge_index using KNN over node features
    edge_index = build_knn_edge_index(x_np, k=k)


    # Get subject's age and convert to tensor
    y = torch.tensor([age_dict[subj_id]], dtype=torch.float32)


    # Create PyG Data object
    data = Data(x=x, edge_index=edge_index, y=y)
    data.subject_id = subj_id  # optional: store ID for reference
    return data

# %%
# === STEP 3: Loop through all subjects and build their graphs ===
graph_data_list = []

for subj_id in column_data:
    if subj_id in age_dict:
        graph = build_graph_from_subject(subj_id, column_data, age_dict, k=10)
        graph_data_list.append(graph)
        print(f" Built graph for subject {subj_id} with {graph.num_nodes} nodes")
    else:
        print(f"[WARNING] No age found for subject {subj_id}")
# Out:
#  Built graph for subject 02110 with 68 nodes
#  Built graph for subject 02363 with 68 nodes
#  Built graph for subject 02373 with 68 nodes
#  Built graph for subject 02386 with 68 nodes
#  Built graph for subject 02390 with 68 nodes
#  Built graph for subject 02231 with 68 nodes
#  Built graph for subject 02402 with 68 nodes
#  Built graph for subject 02410 with 68 nodes
#  Built graph for subject 02421 with 68 nodes
#  Built graph for subject 01912 with 68 nodes
#  Built graph for subject 02424 with 68 nodes
#  Built graph for subject 02446 with 68 nodes
#  Built graph for subject 02451 with 68 nodes
#  Built graph for subject 02485 with 68 nodes
#  Built graph for subject 02473 with 68 nodes
#  Built graph for subject 02491 with 68 nodes
#  Built graph for subject 02506 with 68 nodes
#  Built graph for subject 02524 with 68 nodes
#  Built graph for subject 02535 with 68 nodes
#  Built graph for subject 02654 with 68 nodes
#  Built graph for subject 02666 with 68 nodes
#  Built graph for subject 02690 with 68 nodes
#  Built graph for subject 02695 with 68 nodes
#  Built graph for subject 02715 with 68 nodes
#  Built graph for subject 02720 with 68 nodes
#  Built graph for subject 02737 with 68 nodes
#  Built graph for subject 02753 with 68 nodes
#  Built graph for subject 02227 with 68 nodes
#  Built graph for subject 02765 with 68 nodes
#  Built graph for subject 02771 with 68 nodes
#  Built graph for subject 02781 with 68 nodes
#  Built graph for subject 02802 with 68 nodes
#  Built graph for subject 02804 with 68 nodes
#  Built graph for subject 02813 with 68 nodes
#  Built graph for subject 02817 with 68 nodes
#  Built graph for subject 02840 with 68 nodes
#  Built graph for subject 02877 with 68 nodes
#  Built graph for subject 02898 with 68 nodes
#  Built graph for subject 02926 with 68 nodes
#  Built graph for subject 02938 with 68 nodes
#  Built graph for subject 02939 with 68 nodes
#  Built graph for subject 02954 with 68 nodes
#  Built graph for subject 03010 with 68 nodes
#  Built graph for subject 02320 with 68 nodes
#  Built graph for subject 03028 with 68 nodes
#  Built graph for subject 03033 with 68 nodes
#  Built graph for subject 03034 with 68 nodes
#  Built graph for subject 03045 with 68 nodes
#  Built graph for subject 03069 with 68 nodes
#  Built graph for subject 03225 with 68 nodes
#  Built graph for subject 03265 with 68 nodes
#  Built graph for subject 03293 with 68 nodes
#  Built graph for subject 03308 with 68 nodes
#  Built graph for subject 03343 with 68 nodes
#  Built graph for subject 03350 with 68 nodes
#  Built graph for subject 03378 with 68 nodes
#  Built graph for subject 03391 with 68 nodes
#  Built graph for subject 03847 with 68 nodes
#  Built graph for subject 03889 with 68 nodes
#  Built graph for subject 03896 with 68 nodes
#  Built graph for subject 00775 with 68 nodes
#  Built graph for subject 04493 with 68 nodes
#  Built graph for subject 01412 with 68 nodes
#  Built graph for subject 04526 with 68 nodes
#  Built graph for subject 01470 with 68 nodes
#  Built graph for subject 01619 with 68 nodes

# %%
#Visualize graph

import matplotlib.pyplot as plt
import networkx as nx
from torch_geometric.utils import to_networkx


# === Pick the first subject's graph ===
graph = graph_data_list[0]

# === Convert PyG graph to NetworkX for visualization ===
G = to_networkx(graph, to_undirected=True)

# === Optional: layout (slower for large graphs) ===
pos = nx.spring_layout(G, seed=42)  # force-directed layout

# === Plot ===
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=10, node_color='steelblue', edge_color='gray', alpha=0.6, width=0.5)

plt.title(f"Subject {graph.subject_id} – {graph.num_nodes} nodes")
plt.axis('off')
plt.show()

# %%
#####################  DEVICE CONFIGURATION  #######################

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
#DEFINE MODEL GCNs
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, BatchNorm

class BrainAgeGNN(torch.nn.Module):
    def __init__(self, input_dim=21):  # ← set to 21 features per node
        super(BrainAgeGNN, self).__init__()

        self.conv1 = GCNConv(input_dim, 64)
        self.bn1 = BatchNorm(64)

        self.conv2 = GCNConv(64, 128)
        self.bn2 = BatchNorm(128)

        self.conv3 = GCNConv(128, 128)
        self.bn3 = BatchNorm(128)

        self.fc = torch.nn.Linear(128, 1)
        self.dropout = torch.nn.Dropout(p=0.5)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = F.relu(self.bn2(self.conv2(x, edge_index)))
        x_residual = x
        x = F.relu(self.bn3(self.conv3(x, edge_index)))
        x = x + x_residual

        x = global_mean_pool(x, batch)
        x = self.dropout(x)
        x = self.fc(x)

        return x.view(-1)

# %%
  #train and eval funcions  
    
from torch.optim import Adam
from torch_geometric.loader import DataLoader  # Usamos el DataLoader de torch_geometric

def train(model, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)  # GPU
        optimizer.zero_grad()
        output = model(data).view(-1)
        loss = criterion(output, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)


def evaluate(model, test_loader, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)  # GPU
            output = model(data).view(-1)
            loss = criterion(output, data.y)
            total_loss += loss.item()
    return total_loss / len(test_loader)

# %%
#Training

import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd

# Training settings
epochs = 300
patience = 40
k = 7  # Number of folds
batch_size = 6

# === Initialize loss and tracking ===
all_train_losses = []
all_test_losses = []
all_early_stopping_epochs = []

# === Extract subject IDs from graph list ===
graph_subject_ids = [data.subject_id for data in graph_data_list]

# === Get matching ages in the same order ===
ages = np.array([age_dict[subj_id] for subj_id in graph_subject_ids])

# === Create age bins for stratification ===
age_bins = pd.qcut(ages, q=5, labels=False)  # 5 quantiles

# %%
# Final check
print("Total subjects:", len(graph_data_list))
print("Total age bins:", len(age_bins))

from sklearn.model_selection import StratifiedKFold
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import torch
import numpy as np
from torch_geometric.loader import DataLoader
# Out:
# Total subjects: 66
# Total age bins: 66

# %%
# Stratified split by age bins
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
repeats_per_fold = 10

# %%
# === Build age vector and age bins ===
graph_subject_ids = [data.subject_id for data in graph_data_list]
ages = np.array([age_dict[subj_id] for subj_id in graph_subject_ids])
age_bins = pd.qcut(ages, q=5, labels=False)

for fold, (train_idx, test_idx) in enumerate(skf.split(graph_data_list, age_bins)):
    print(f'\n--- Fold {fold+1}/{k} ---')

    train_data = [graph_data_list[i] for i in train_idx]
    test_data = [graph_data_list[i] for i in test_idx]

    fold_train_losses = []
    fold_test_losses = []

    for repeat in range(repeats_per_fold):
        print(f'  > Repeat {repeat+1}/{repeats_per_fold}')

        early_stop_epoch = None
        seed_everything(42 + repeat)

        train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

        model = BrainAgeGNN(input_dim=21).to(device)

        optimizer = AdamW(model.parameters(), lr=0.002, weight_decay=1e-4)
        scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
        criterion = torch.nn.SmoothL1Loss(beta=1)

        best_loss = float('inf')
        patience_counter = 0

        train_losses = []
        test_losses = []

        for epoch in range(epochs):
            train_loss = train(model, train_loader, optimizer, criterion)
            test_loss = evaluate(model, test_loader, criterion)

            train_losses.append(train_loss)
            test_losses.append(test_loss)

            if test_loss < best_loss:
                best_loss = test_loss
                patience_counter = 0
                torch.save(model.state_dict(), f"column_md_model_fold_{fold+1}_rep_{repeat+1}.pt")
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    early_stop_epoch = epoch + 1
                    print(f"    Early stopping triggered at epoch {early_stop_epoch}.")
                    break

            scheduler.step()

        if early_stop_epoch is None:
            early_stop_epoch = epochs

        all_early_stopping_epochs.append((fold + 1, repeat + 1, early_stop_epoch))

        fold_train_losses.append(train_losses)
        fold_test_losses.append(test_losses)

    all_train_losses.append(fold_train_losses)
    all_test_losses.append(fold_test_losses)
# Out:
# --- Fold 1/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 55.
#   > Repeat 2/10
#     Early stopping triggered at epoch 55.
#   > Repeat 3/10
#     Early stopping triggered at epoch 60.
#   > Repeat 4/10
#     Early stopping triggered at epoch 82.
#   > Repeat 5/10
#     Early stopping triggered at epoch 55.
#   > Repeat 6/10
#     Early stopping triggered at epoch 66.
#   > Repeat 7/10
#     Early stopping triggered at epoch 54.
#   > Repeat 8/10
#     Early stopping triggered at epoch 90.
#   > Repeat 9/10
#     Early stopping triggered at epoch 61.
#   > Repeat 10/10
#     Early stopping triggered at epoch 69.
#
# --- Fold 2/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 87.
#   > Repeat 2/10
#     Early stopping triggered at epoch 66.
#   > Repeat 3/10
#     Early stopping triggered at epoch 127.
#   > Repeat 4/10
#     Early stopping triggered at epoch 96.
#   > Repeat 5/10
#     Early stopping triggered at epoch 85.
#   > Repeat 6/10
#     Early stopping triggered at epoch 75.
#   > Repeat 7/10
#     Early stopping triggered at epoch 97.
#   > Repeat 8/10
#     Early stopping triggered at epoch 80.
#   > Repeat 9/10
#     Early stopping triggered at epoch 68.
#   > Repeat 10/10
#     Early stopping triggered at epoch 84.
#
# --- Fold 3/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 95.
#   > Repeat 2/10
#     Early stopping triggered at epoch 75.
#   > Repeat 3/10
#     Early stopping triggered at epoch 107.
#   > Repeat 4/10
#     Early stopping triggered at epoch 61.
#   > Repeat 5/10
#     Early stopping triggered at epoch 96.
#   > Repeat 6/10
#     Early stopping triggered at epoch 96.
#   > Repeat 7/10
#     Early stopping triggered at epoch 107.
#   > Repeat 8/10
#     Early stopping triggered at epoch 89.
#   > Repeat 9/10
#     Early stopping triggered at epoch 91.
#   > Repeat 10/10
#     Early stopping triggered at epoch 120.
#
# --- Fold 4/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 67.
#   > Repeat 2/10
#     Early stopping triggered at epoch 65.
#   > Repeat 3/10
#     Early stopping triggered at epoch 64.
#   > Repeat 4/10
#     Early stopping triggered at epoch 54.
#   > Repeat 5/10
#     Early stopping triggered at epoch 53.
#   > Repeat 6/10
#     Early stopping triggered at epoch 64.
#   > Repeat 7/10
#     Early stopping triggered at epoch 65.
#   > Repeat 8/10
#     Early stopping triggered at epoch 65.
#   > Repeat 9/10
#     Early stopping triggered at epoch 77.
#   > Repeat 10/10
#     Early stopping triggered at epoch 54.
#
# --- Fold 5/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 68.
#   > Repeat 2/10
#     Early stopping triggered at epoch 69.
#   > Repeat 3/10
#     Early stopping triggered at epoch 81.
#   > Repeat 4/10
#     Early stopping triggered at epoch 127.
#   > Repeat 5/10
#     Early stopping triggered at epoch 109.
#   > Repeat 6/10
#     Early stopping triggered at epoch 75.
#   > Repeat 7/10
#     Early stopping triggered at epoch 67.
#   > Repeat 8/10
#     Early stopping triggered at epoch 66.
#   > Repeat 9/10
#     Early stopping triggered at epoch 62.
#   > Repeat 10/10
#     Early stopping triggered at epoch 70.
#
# --- Fold 6/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 93.
#   > Repeat 2/10
#     Early stopping triggered at epoch 57.
#   > Repeat 3/10
#     Early stopping triggered at epoch 105.
#   > Repeat 4/10
#     Early stopping triggered at epoch 65.
#   > Repeat 5/10
#     Early stopping triggered at epoch 116.
#   > Repeat 6/10
#     Early stopping triggered at epoch 89.
#   > Repeat 7/10
#     Early stopping triggered at epoch 73.
#   > Repeat 8/10
#     Early stopping triggered at epoch 83.
#   > Repeat 9/10
#     Early stopping triggered at epoch 62.
#   > Repeat 10/10
#     Early stopping triggered at epoch 63.
#
# --- Fold 7/7 ---
#   > Repeat 1/10
#     Early stopping triggered at epoch 98.
#   > Repeat 2/10
#     Early stopping triggered at epoch 144.
#   > Repeat 3/10
#     Early stopping triggered at epoch 95.
#   > Repeat 4/10
#     Early stopping triggered at epoch 69.
#   > Repeat 5/10
#     Early stopping triggered at epoch 98.
#   > Repeat 6/10
#     Early stopping triggered at epoch 70.
#   > Repeat 7/10
#     Early stopping triggered at epoch 89.
#   > Repeat 8/10
#     Early stopping triggered at epoch 65.
#   > Repeat 9/10
#     Early stopping triggered at epoch 144.
#   > Repeat 10/10
#     Early stopping triggered at epoch 65.

# %%
##################  LEARNING CURVE (ALL FOLDS + REPEATS)  ##################

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))

# Plot learning curves for each fold and repetition
for fold in range(k):
    for rep in range(repeats_per_fold):
        plt.plot(all_train_losses[fold][rep], label=f'Train Loss - Fold {fold+1} Rep {rep+1}', linestyle='dashed', alpha=0.5)
        plt.plot(all_test_losses[fold][rep], label=f'Test Loss - Fold {fold+1} Rep {rep+1}', alpha=0.5)

plt.xlabel("Epochs")
plt.ylabel("Smooth L1 Loss")
plt.title("Learning Curve (All Folds & Repeats – Column-Based GCN)")
plt.legend(loc="upper right", fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\2581121043.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
#######################  LEARNING CURVE (MEAN ± STD)  ########################
# Compute mean and std per epoch across all folds and repetitions
avg_train = []
avg_test = []

for epoch in range(epochs):
    epoch_train = []
    epoch_test = []
    for fold in range(k):
        for rep in range(repeats_per_fold):
            if epoch < len(all_train_losses[fold][rep]):
                epoch_train.append(all_train_losses[fold][rep][epoch])
                epoch_test.append(all_test_losses[fold][rep][epoch])
    avg_train.append((np.mean(epoch_train), np.std(epoch_train)))
    avg_test.append((np.mean(epoch_test), np.std(epoch_test)))
# Out:
# d:\Anaconda\install\envs\brain_age_gnn\Lib\site-packages\numpy\_core\fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\Anaconda\install\envs\brain_age_gnn\Lib\site-packages\numpy\_core\_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# d:\Anaconda\install\envs\brain_age_gnn\Lib\site-packages\numpy\_core\_methods.py:218: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# d:\Anaconda\install\envs\brain_age_gnn\Lib\site-packages\numpy\_core\_methods.py:175: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# d:\Anaconda\install\envs\brain_age_gnn\Lib\site-packages\numpy\_core\_methods.py:210: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# Unpack values
train_mean, train_std = zip(*avg_train)
test_mean, test_std = zip(*avg_test)

# %%
# Plot mean ± std
plt.figure(figsize=(10, 6))

plt.plot(train_mean, label="Train Mean", color="blue")
plt.fill_between(range(epochs), np.array(train_mean) - np.array(train_std),
                 np.array(train_mean) + np.array(train_std), color="blue", alpha=0.3)

plt.plot(test_mean, label="Test Mean", color="orange")
plt.fill_between(range(epochs), np.array(test_mean) - np.array(test_std),
                 np.array(test_mean) + np.array(test_std), color="orange", alpha=0.3)

plt.xlabel("Epoch")
plt.ylabel("Smooth L1 Loss")
plt.title("Learning Curve (Mean ± Std – GCN on Column-Based Graphs)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
##################  PREDICTION & METRIC ANALYSIS (COLUMN-BASED GRAPHS)  ##################

from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import matplotlib.pyplot as plt


# === Initialize storage ===
fold_mae_list = []
fold_r2_list = []
fold_rmse_list = []

all_y_true = []
all_y_pred = []

for fold, (train_idx, test_idx) in enumerate(skf.split(graph_data_list, age_bins)):
    print(f'\n--- Evaluating Fold {fold+1}/{k} ---')

    test_data = [graph_data_list[i] for i in test_idx]
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

    repeat_maes = []
    repeat_r2s = []
    repeat_rmses = []

    for rep in range(repeats_per_fold):
        print(f"  > Repeat {rep+1}/{repeats_per_fold}")

        model = BrainAgeGNN(input_dim=21).to(device)  # ← Your model

        model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
        model.eval()

        y_true_repeat = []
        y_pred_repeat = []

        with torch.no_grad():
            for data in test_loader:
                data = data.to(device)
                output = model(data).view(-1)
                y_pred_repeat.extend(output.cpu().tolist())
                y_true_repeat.extend(data.y.cpu().tolist())


        # Compute metrics
        mae = mean_absolute_error(y_true_repeat, y_pred_repeat)
        r2 = r2_score(y_true_repeat, y_pred_repeat)
        rmse = np.sqrt(mean_squared_error(y_true_repeat, y_pred_repeat))

        repeat_maes.append(mae)
        repeat_r2s.append(r2)
        repeat_rmses.append(rmse)

        all_y_true.extend(y_true_repeat)
        all_y_pred.extend(y_pred_repeat)

    fold_mae_list.append(repeat_maes)
    fold_r2_list.append(repeat_r2s)
    fold_rmse_list.append(repeat_rmses)

    print(f">> Fold {fold+1} | MAE: {np.mean(repeat_maes):.2f} ± {np.std(repeat_maes):.2f} | "
          f"R²: {np.mean(repeat_r2s):.2f} ± {np.std(repeat_r2s):.2f} | "
          f"RMSE: {np.mean(repeat_rmses):.2f} ± {np.std(repeat_rmses):.2f}")
# Out:
# --- Evaluating Fold 1/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
#   > Repeat 4/10
#   > Repeat 5/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
#   > Repeat 9/10
#   > Repeat 10/10
# >> Fold 1 | MAE: 7.61 ± 0.47 | R²: 0.54 ± 0.04 | RMSE: 10.23 ± 0.45
#
# --- Evaluating Fold 2/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 4/10
#   > Repeat 5/10
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 9/10
#   > Repeat 10/10
# >> Fold 2 | MAE: 5.10 ± 0.18 | R²: 0.76 ± 0.03 | RMSE: 6.87 ± 0.38
#
# --- Evaluating Fold 3/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 4/10
#   > Repeat 5/10
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
#   > Repeat 9/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 10/10
# >> Fold 3 | MAE: 4.15 ± 0.23 | R²: 0.81 ± 0.02 | RMSE: 5.53 ± 0.33
#
# --- Evaluating Fold 4/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
#   > Repeat 4/10
#   > Repeat 5/10
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
#   > Repeat 9/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 10/10
# >> Fold 4 | MAE: 8.06 ± 0.53 | R²: 0.47 ± 0.10 | RMSE: 10.45 ± 0.96
#
# --- Evaluating Fold 5/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
#   > Repeat 4/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 5/10
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
#   > Repeat 9/10
# ...
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 10/10
# >> Fold 6 | MAE: 3.19 ± 0.31 | R²: 0.89 ± 0.03 | RMSE: 4.27 ± 0.50
#
# --- Evaluating Fold 7/7 ---
#   > Repeat 1/10
#   > Repeat 2/10
#   > Repeat 3/10
#   > Repeat 4/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 5/10
#   > Repeat 6/10
#   > Repeat 7/10
#   > Repeat 8/10
#   > Repeat 9/10
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model
#   > Repeat 10/10
# >> Fold 7 | MAE: 6.51 ± 0.27 | R²: 0.69 ± 0.03 | RMSE: 8.90 ± 0.42
# C:\Users\22679\AppData\Local\Temp\ipykernel_15612\468982488.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"column_md_model_fold_{fold+1}_rep_{rep+1}.pt"))  # Load saved model

# %%
# === Final aggregate results ===
all_maes = np.array(fold_mae_list).flatten()
all_r2s = np.array(fold_r2_list).flatten()
all_rmses = np.array(fold_rmse_list).flatten()

print("\n================== FINAL METRICS (COLUMN-BASED GCN) ==================")
print(f"Global MAE:  {np.mean(all_maes):.2f} ± {np.std(all_maes):.2f}")
print(f"Global R²:   {np.mean(all_r2s):.2f} ± {np.std(all_r2s):.2f}")
print(f"Global RMSE: {np.mean(all_rmses):.2f} ± {np.std(all_rmses):.2f}")
print("=======================================================================")
# Out:
# ================== FINAL METRICS (COLUMN-BASED GCN) ==================
# Global MAE:  5.96 ± 1.74
# Global R²:   0.69 ± 0.14
# Global RMSE: 7.91 ± 2.29
# =======================================================================

# %%
######################  PLOT TRUE VS PREDICTED AGES (COLUMN-BASED)  ######################

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 6))

# Scatter plot of true vs predicted ages
plt.scatter(all_y_true, all_y_pred, alpha=0.7, edgecolors='k', label="Predictions")


# Diagonal (ideal prediction)
min_val = min(min(all_y_true), min(all_y_pred))
max_val = max(max(all_y_true), max(all_y_pred))
margin = (max_val - min_val) * 0.05
plt.plot([min_val, max_val], [min_val, max_val], color="red", linestyle="dashed", label="Ideal (y=x)")
plt.xlim(min_val - margin, max_val + margin)
plt.ylim(min_val - margin, max_val + margin)


# Metrics text box with MAE, R² and RMSE
textstr = (f"MAE: {np.mean(all_maes):.2f} ± {np.std(all_maes):.2f}\n"
           f"R²: {np.mean(all_r2s):.2f} ± {np.std(all_r2s):.2f}\n"
           f"RMSE: {np.mean(all_rmses):.2f} ± {np.std(all_rmses):.2f}")

plt.text(0.95, 0.05, textstr, transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightgray"))

# Labels and style
plt.xlabel("Real Age")
plt.ylabel("Predicted Age")
plt.title("Predicted vs Real Age — Columnar GCN (All Folds/Repeats)")
plt.legend(loc="upper left")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Evaluation done

# %%
############################################

# FINAL MODEL TRAINING ON HEALTHY + FAMILIAL

############################################

print("\n=== Training Final Model on All Healthy + Familial Subjects ===")

from torch_geometric.loader import DataLoader


# === Create DataLoader with all filtered subjects ===
final_train_loader = DataLoader(graph_data_list, batch_size=6, shuffle=True)


# === Initialize model ===
final_model = BrainAgeGNN(input_dim=21).to(device)


# === Optimizer and learning rate scheduler ===
optimizer = torch.optim.AdamW(final_model.parameters(), lr=0.002, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)


# === Loss function ===
criterion = torch.nn.SmoothL1Loss(beta=1)
# Out:
# === Training Final Model on All Healthy + Familial Subjects ===

# %%
# === Train for fixed number of epochs (no early stopping) ===
epochs = 100

for epoch in range(epochs):
    final_model.train()
    total_loss = 0

    for data in final_train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = final_model(data).view(-1)
        loss = criterion(output, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(final_train_loader)
    print(f"Epoch {epoch+1:03d} | Loss: {avg_loss:.4f}")

    scheduler.step()
# Out:
# Epoch 001 | Loss: 49.5431
# Epoch 002 | Loss: 47.0370
# Epoch 003 | Loss: 44.6606
# Epoch 004 | Loss: 42.0888
# Epoch 005 | Loss: 39.0253
# Epoch 006 | Loss: 35.5851
# Epoch 007 | Loss: 31.4223
# Epoch 008 | Loss: 27.5680
# Epoch 009 | Loss: 23.2735
# Epoch 010 | Loss: 18.7858
# Epoch 011 | Loss: 15.3908
# Epoch 012 | Loss: 12.3844
# Epoch 013 | Loss: 9.0223
# Epoch 014 | Loss: 8.1229
# Epoch 015 | Loss: 8.0540
# Epoch 016 | Loss: 8.2947
# Epoch 017 | Loss: 6.8582
# Epoch 018 | Loss: 9.0228
# Epoch 019 | Loss: 7.9583
# Epoch 020 | Loss: 7.1052
# Epoch 021 | Loss: 8.3048
# Epoch 022 | Loss: 7.6820
# Epoch 023 | Loss: 7.2308
# Epoch 024 | Loss: 8.0459
# Epoch 025 | Loss: 8.3656
# Epoch 026 | Loss: 6.7287
# Epoch 027 | Loss: 6.8731
# Epoch 028 | Loss: 9.3003
# Epoch 029 | Loss: 7.4514
# Epoch 030 | Loss: 8.0348
# Epoch 031 | Loss: 7.9528
# Epoch 032 | Loss: 6.6765
# Epoch 033 | Loss: 7.9119
# Epoch 034 | Loss: 7.4430
# Epoch 035 | Loss: 8.1905
# Epoch 036 | Loss: 7.7838
# Epoch 037 | Loss: 7.7800
# Epoch 038 | Loss: 6.3235
# Epoch 039 | Loss: 8.0718
# Epoch 040 | Loss: 7.2645
# Epoch 041 | Loss: 6.4992
# Epoch 042 | Loss: 8.3727
# Epoch 043 | Loss: 7.3181
# Epoch 044 | Loss: 6.4792
# Epoch 045 | Loss: 7.0244
# Epoch 046 | Loss: 8.0795
# Epoch 047 | Loss: 8.1350
# Epoch 048 | Loss: 8.7915
# Epoch 049 | Loss: 7.7375
# Epoch 050 | Loss: 6.7653
# Epoch 051 | Loss: 7.4182
# Epoch 052 | Loss: 7.3296
# Epoch 053 | Loss: 6.7543
# Epoch 054 | Loss: 7.5861
# Epoch 055 | Loss: 6.9457
# Epoch 056 | Loss: 6.3516
# Epoch 057 | Loss: 8.0469
# Epoch 058 | Loss: 7.6139
# Epoch 059 | Loss: 6.7865
# Epoch 060 | Loss: 6.8628
# Epoch 061 | Loss: 7.7055
# Epoch 062 | Loss: 8.5166
# Epoch 063 | Loss: 6.8400
# Epoch 064 | Loss: 5.8972
# Epoch 065 | Loss: 7.2913
# Epoch 066 | Loss: 6.8298
# Epoch 067 | Loss: 7.3626
# Epoch 068 | Loss: 8.3811
# Epoch 069 | Loss: 7.4292
# Epoch 070 | Loss: 8.2025
# Epoch 071 | Loss: 6.9914
# Epoch 072 | Loss: 5.7846
# Epoch 073 | Loss: 6.4732
# Epoch 074 | Loss: 7.8419
# Epoch 075 | Loss: 6.7445
# Epoch 076 | Loss: 6.5045
# Epoch 077 | Loss: 9.7623
# Epoch 078 | Loss: 7.8888
# Epoch 079 | Loss: 7.5247
# Epoch 080 | Loss: 7.2854
# Epoch 081 | Loss: 6.4699
# Epoch 082 | Loss: 5.9498
# Epoch 083 | Loss: 8.0524
# Epoch 084 | Loss: 6.9945
# Epoch 085 | Loss: 6.4603
# Epoch 086 | Loss: 6.4898
# Epoch 087 | Loss: 8.4727
# Epoch 088 | Loss: 7.1907
# Epoch 089 | Loss: 6.6621
# Epoch 090 | Loss: 7.7775
# Epoch 091 | Loss: 6.3470
# Epoch 092 | Loss: 7.7980
# Epoch 093 | Loss: 7.0896
# Epoch 094 | Loss: 5.3929
# Epoch 095 | Loss: 7.0820
# Epoch 096 | Loss: 6.7726
# Epoch 097 | Loss: 7.1639
# Epoch 098 | Loss: 7.5946
# Epoch 099 | Loss: 6.5028
# Epoch 100 | Loss: 7.3490

# %%
# === Save final model ===
torch.save(final_model.state_dict(), "column_md_model_trained_on_all_healthy.pt")
print("\nFinal model saved as 'model_trained_on_all_healthy.pt'")
# Out:
# Final model saved as 'model_trained_on_all_healthy.pt'

# %%
# === Notes ===

# We selected 100 epochs for the final model training based on the early stopping

# behavior observed during cross-validation. Most runs converged between 60–90 epochs (mean=86)

# so 100 allows for full convergence without early stopping.
